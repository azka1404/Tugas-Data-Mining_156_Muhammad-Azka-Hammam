# %% [markdown]
# <a href="https://colab.research.google.com/github/azka1404/Tugas-Data-Mining_156_Muhammad-Azka-Hammam/blob/main/Tugas%20Pertemuan%201%20Data%20Mining.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
print("Jumlah total mahasiswa:", df.shape[0])
print("Jumlah total variabel:", df.shape[1])
# Out:
# Jumlah total mahasiswa: 5000
# Jumlah total variabel: 21

# %% [markdown]
# data.shape[0] menghitung jumlah baris (observasi).
#
# data.shape[1] menghitung jumlah kolom (variabel).
#
# Output menunjukkan:
#
# Jumlah total mahasiswa: 5000
#
# Jumlah total variabel: 21
#
# Artinya seluruh analisis dilakukan terhadap 5000 mahasiswa. Jumlah ini cukup besar sehingga model machine learning dapat belajar dengan baik dan hasilnya lebih stabil.

# %%
data = pd.read_csv('/content/ultimate_student_productivity_dataset_5000.csv')
data.head()
# Out:
#    student_id  age gender academic_level  study_hours  self_study_hours  \
# 0           1   18  Other    High School         7.64              1.56
# 1           2   18  Other    High School         2.21              2.22
# 2           3   22   Male    High School         3.45              0.00
# 3           4   17  Other    High School         5.75              2.08
# 4           5   19  Other    High School         6.83              1.72
#
#    online_classes_hours  social_media_hours  gaming_hours  sleep_hours  ...  \
# 0                  2.20                3.05          2.19         6.52  ...
# 1                  2.10                1.65          2.55         5.97  ...
# 2                  0.29                1.34          2.08         8.39  ...
# 3                  3.01                2.27          2.20         6.31  ...
# 4                  3.33                2.65          0.70         8.01  ...
#
# ...

# %% [markdown]
# Dataset ultimate_student_productivity_dataset_5000.csv terdiri dari 5000 data mahasiswa yang berhasil dimuat ke dalam DataFrame.
#
# Setiap baris merepresentasikan satu mahasiswa, dan setiap kolom merepresentasikan variabel yang mempengaruhi produktivitas mahasiswa, seperti: Jam belajar, Jam tidur, Penggunaan media sosial, Nilai ujian, Skor produktivitas
#
# Dataset ini digunakan untuk menganalisis hubungan antara kebiasaan belajar, gaya hidup, dan tingkat produktivitas mahasiswa.

# %%
data.describe()
# Out:
#         student_id          age  study_hours  self_study_hours  \
# count  5000.000000  5000.000000  5000.000000       5000.000000
# mean   2500.500000    20.520400     4.539594          2.478734
# std    1443.520003     2.870406     1.821665          1.177990
# min       1.000000    16.000000     0.000000          0.000000
# 25%    1250.750000    18.000000     3.250000          1.660000
# 50%    2500.500000    20.000000     4.530000          2.480000
# 75%    3750.250000    23.000000     5.760000          3.290000
# max    5000.000000    25.000000    11.840000          7.410000
#
#        online_classes_hours  social_media_hours  gaming_hours  sleep_hours  \
# count           5000.000000         5000.000000   5000.000000  5000.000000
# mean               2.011984            2.998086      1.564514     7.016492
# std                0.983906            1.467949      1.110807     1.163692
# min                0.000000            0.000000      0.000000     4.000000
# ...

# %% [markdown]
# Output tersebut menunjukkan statistik deskriptif dari variabel numerik.
#
# Analisis:
#
# Mahasiswa rata-rata belajar sekitar 4,5 jam per hari
#
# Mahasiswa menggunakan media sosial sekitar 3 jam per hari
#
# Mahasiswa tidur sekitar 7 jam per hari
#
# Tingkat produktivitas rata-rata berada pada kategori sedang
#
# Terdapat variasi produktivitas yang cukup besar antar mahasiswa
#
# Ini menunjukkan bahwa produktivitas mahasiswa dipengaruhi oleh keseimbangan antara aktivitas akademik dan non-akademik.

# %%
study = data['study_hours']

count_study = study.value_counts()

unique_study = study.drop_duplicates()

print(count_study)
# Out:
# study_hours
# 0.00    29
# 4.94    19
# 5.22    19
# 5.47    18
# 3.72    17
#         ..
# 8.45     1
# 9.61     1
# 0.85     1
# 0.88     1
# 8.88     1
# Name: count, Length: 840, dtype: int64

# %% [markdown]
# Output menunjukkan distribusi jumlah mahasiswa berdasarkan jam belajar per hari.
#
# Jam belajar 5 jam per hari merupakan yang paling dominan, menunjukkan bahwa mayoritas mahasiswa memiliki intensitas belajar sedang.
#
# Mahasiswa dengan jam belajar sangat tinggi jumlahnya lebih sedikit.
#
# Hal ini menunjukkan bahwa sebagian besar mahasiswa memiliki kebiasaan belajar yang relatif stabil.
